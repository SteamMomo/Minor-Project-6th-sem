# %%
import pandas as pd
import re
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import time
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix
import gensim
import numpy as np

# %%
imdb = "E:/Momo/Datasets/imdbreviews/IMDB Dataset.csv"

df = pd.read_csv(imdb)
print(df.shape)
df.head()
# Out:
# (50000, 2)
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
def clean_text(text):
    text=str(text).lower()
    text=re.sub('\[.*?\]', '', text)
    text=re.sub('https?://\S+|www\.\S+', '', text)
    text=re.sub('<.*?>+', '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = gensim.parsing.remove_stopwords(text)
    return text

df['review']=df['review'].apply(clean_text)
df.head()
# Out:
#                                               review sentiment
# 0  reviewers mentioned watching oz episode you'll...  positive
# 1  wonderful little production. filming technique...  positive
# 2  thought wonderful way spend time hot summer we...  positive
# 3  basically there's family little boy (jake) thi...  negative
# 4  petter mattei's "love time money" visually stu...  positive

# %%
# Split features and labels
X = df["review"]
y = df["sentiment"]

# Split train and test set
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.4,random_state=0)

print(X_train.shape, X_test.shape)
# Out:
# (30000,) (20000,)

# %%
# Create feature vectors
vectorizer = CountVectorizer()
train_vectors = vectorizer.fit_transform(X_train)
test_vectors = vectorizer.transform(X_test)

# %%
temp = vectorizer.vocabulary_
print(len(temp))
print(X_train[2])
print(temp)
print(train_vectors[1])
# Out:
# 82172
# thought wonderful way spend time hot summer weekend, sitting air conditioned theater watching light-hearted comedy. plot simplistic, dialogue witty characters likable (even bread suspected serial killer). disappointed realize match point : risk addiction, thought proof woody allen fully control style grown love.this i'd laughed woody's comedies years (dare decade?). i've impressed scarlet johanson, managed tone "sexy" image jumped right average, spirited young woman.this crown jewel career, wittier "devil wears prada" interesting "superman" great comedy friends.
# {'liked': 42034, 'stanley': 68664, 'iris': 37138, 'much': 48147, 'acting': 662, 'good': 30028, 'story': 69337, 'unique': 76532, 'interesting': 36691, 'arrangement': 3665, 'absence': 312, 'violence': 78371, 'porno': 55630, 'sex': 64547, 'refreshing': 59348, 'characters': 11948, 'convincing': 15282, 'felt': 25711, 'like': 42030, 'understand': 76130, 'feelings': 25624, 'enjoyable': 23228, 'movie': 48037, 'mummy': 48320, 'curse': 16841, 'series': 64399, 'kharis': 39398, 'films': 26147, 'creativity': 16152, 'run': 61994, 'somewhat': 67344, 'dry': 21393, 'time': 73320, 'one': 51170, 'mate': 44887, 'ananka': 2452, 'end': 23061, 'bayous': 5920, 'louisiana': 42888, 'resurrection': 60376, 'searches': 63838, 'beloved': 6457, 'princess': 56475, 'isn': 37312, 'entirely': 23396, 'clear': 13231, 'people': 53662, 'trying': 75047, 'them': 72662, 'viewer': 78214, 'assured': 4094, 'murders': 48389, 'the': 72596, 'watchable': 79270, 'wasn': 79236, 'special': 67805, 'feeling': 25622, 'seen': 64007, 'before': 6231, 'frankly': 27569, 'apart': 3052, 'original': 51559, 'boris': 8408, 'karloff': 38952, 'movies': 48061, 'favorites': 25487, 'old': 51059, 'universal': 76555, 'horrors': 34099, 'they': 72793, 're': 58674, 'bad': 5004, 'bit': 7259, 'repetitive': 59980, 'there': 72727, 'great': 30564, 'scenes': 63189, 'scene': 63180, 'coming': 14082, 'life': 41948, 'swamp': 70854, 'instance': 36482, 'overall': 51982, 'didn': 19311, 'me': 45439, 'it': 37362, 'worth': 80921, 'seeing': 63986, 'want': 79092, 'completest': 14339, 'pass': 53042, 'best': 6766, 'show': 65343, 'hilarious': 33265, 'mockumentary': 47163, 'takes': 71473, 'world': 80865, 'dog': 20499, 'shows': 65378, 'owners': 52270, 'prepare': 56229, 'event': 24088, 'thing': 72845, 'separates': 64301, 'real': 58734, 'dogs': 20531, 'act': 657, 'sane': 62635, 'funny': 28161, 'stuff': 69730, 'top': 73835, 'notch': 50188, 'cast': 11192, 'includes': 35669, 'eugene': 23984, 'levy': 41802, 'who': 80020, 'co': 13563, 'wrote': 81082, 'film': 26095, 'catherine': 11328, 'hara': 31958, 'parker': 52897, 'posey': 55727, 'michael': 46240, 'mckean': 45333, 'jennifer': 37944, 'coolidge': 15326, 'jane': 37675, 'lynch': 43333, 'christopher': 12715, 'guest': 31076, 'directed': 19598, 'fred': 27654, 'willard': 80243, 'steals': 68874, 'explosively': 24654, 'performance': 53765, 'announcer': 2792, 'says': 63019, 'outrageous': 51888, 'things': 72850, 'plus': 55177, 'cute': 16910, 'too': 73790, 'exactly': 24238, 'laugh': 41103, 'riot': 60997, 'expected': 24542, 'laughs': 41115, 'out': 51786, 'four': 27412, 'david': 17509, 'suchet': 70094, 'poirot': 55279, 'foolproof': 27062, 'gave': 28778, 'outstanding': 51931, 'perfectionist': 53747, 'said': 62340, 'cocktail': 13665, 'napkin': 48879, 'blot': 7742, 'excess': 24316, 'mouth': 48014, 'unbelievable': 75834, 'perfection': 53746, 'view': 78210, 'expressions': 24703, 'detective': 18928, 'face': 24923, 'missed': 46962, 'item': 37385, 'importance': 35412, 'suspects': 70751, 'behavior': 6290, 'beautiful': 6069, 'falls': 25115, 'colors': 13963, 'english': 23183, 'countryside': 15800, 'simply': 65861, 'breath': 8911, 'taking': 71477, 'megan': 45650, 'dodds': 20462, 'bait': 5129, 'sexy': 64582, 'wild': 80186, 'woman': 80673, 'able': 229, 'important': 35414, 'secrets': 63926, 'away': 4728, 'mr': 48115, 'loved': 42931, 'actors': 695, 'but': 9986, 'ms': 48122, 'davis': 17523, 'poor': 55541, 'attempt': 4309, 'accent': 415, 'stiff': 69088, 'makes': 43888, 'compelling': 14280, 'hard': 31986, 'watch': 79268, 'seriously': 64404, 'modern': 47194, 'actor': 692, 'played': 54975, 'role': 61389, 'style': 69820, 'laughed': 41107, 'screen': 63636, 'think': 72853, 'phoned': 54315, 'in': 35529, 'myrna': 48607, 'loy': 42997, 'ingrid': 36191, 'bergman': 6637, 'playing': 54993, 'wife': 80154, 'enjoyed': 23230, 'more': 47698, 'guess': 31069, 'don': 20650, 'get': 29180, 'bette': 6816, 've': 77755, 'thought': 72970, 'plays': 55004, 'herself': 33039, 'matter': 44977, 'she': 64881, 'possible': 55769, 'exception': 24 ...
#   (0, 48037)	2
#   (0, 48320)	7
#   (0, 16841)	2
#   (0, 64399)	1
#   (0, 39398)	2
#   (0, 26147)	1
#   (0, 16152)	1
#   (0, 61994)	1
#   (0, 67344)	1
#   (0, 21393)	1
#   (0, 73320)	1
#   (0, 51170)	2
#   (0, 44887)	1
#   (0, 2452)	2
#   (0, 23061)	2
#   (0, 5920)	1
#   (0, 42888)	2
#   (0, 60376)	1
#   (0, 63838)	1
#   (0, 6457)	1
#   (0, 56475)	1
#   (0, 37312)	1
#   (0, 23396)	1
#   (0, 13231)	1
#   (0, 53662)	1
#   :	:
#   (0, 51059)	1
#   (0, 76555)	1
#   (0, 34099)	1
#   (0, 72793)	1
#   (0, 58674)	1
#   (0, 5004)	1
#   (0, 7259)	1
#   (0, 59980)	1
#   (0, 72727)	1
#   (0, 30564)	1
#   (0, 63189)	1
#   (0, 63180)	1
#   (0, 14082)	1
#   (0, 41948)	1
#   (0, 70854)	1
#   (0, 36482)	1
#   (0, 51982)	1
#   (0, 19311)	1
#   (0, 45439)	1
#   (0, 37362)	1
#   (0, 80921)	1
#   (0, 63986)	1
#   (0, 79092)	2
#   (0, 14339)	1
#   (0, 53042)	1

# %%
model = MultinomialNB()
model.fit(train_vectors, y_train)
y_pred = model.predict(test_vectors)
acc = accuracy_score(y_test, y_pred)
print("Accuracy:", acc)
# Out:
# Accuracy: 0.8558
